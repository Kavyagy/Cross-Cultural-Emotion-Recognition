# %%
import os
import torch
from moviepy.editor import VideoFileClip

# %%
path = '.'
c = 0
files = os.listdir(path)
files.sort()
for file in files:
    if file.endswith('.pt'):
        f = torch.load(file)
        print(file, f.shape)
# Out:
# SAH_C1_S005_P010_VC1_000001_000801.pt torch.Size([25, 768])
# SAH_C1_S009_P017_VC1_004001_006201.pt torch.Size([68, 768])
# SAH_C1_S009_P018_VC1_004321_005367.pt torch.Size([32, 768])
# SAH_C1_S013_P025_VC1_000997_002939.pt torch.Size([60, 768])
# SAH_C1_S013_P025_VC1_006901_008783.pt torch.Size([58, 768])
# SAH_C1_S014_P028_VC1_000588_001854.pt torch.Size([39, 768])
# SAH_C1_S018_P036_VC1_001394_002328.pt torch.Size([29, 768])
# SAH_C1_S022_P044_VC1_007329_008693.pt torch.Size([42, 768])
# SAH_C1_S024_P048_VC1_000845_002039.pt torch.Size([37, 768])
# SAH_C1_S027_P053_VC1_006932_008715.pt torch.Size([55, 768])
# SAH_C1_S027_P054_VC1_000920_002082.pt torch.Size([36, 768])
# SAH_C1_S028_P055_VC1_003774_004919.pt torch.Size([35, 768])
# SAH_C1_S028_P056_VC1_001001_001771.pt torch.Size([24, 768])
# SAH_C1_S029_P057_VC1_003201_004052.pt torch.Size([26, 768])
# SAH_C1_S029_P058_VC1_006573_007472.pt torch.Size([28, 768])
# SAH_C1_S192_P384_VC1_006367_008663.pt torch.Size([71, 768])
# ...
